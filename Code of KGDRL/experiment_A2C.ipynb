# %%
from raw_PPO import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=5*5*12, action_d=5*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=500)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 50/50 [03:35<00:00,  4.30s/it, episode=500, return=-1380.445, makespan=1174.020]

# %%
from raw_PPO import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*5*12, action_d=10*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=500)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 50/50 [11:04<00:00, 13.30s/it, episode=500, return=-2651.062, makespan=2200.937]

# %%
from raw_PPO import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=20*5*12, action_d=20*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 30/30 [32:01<00:00, 64.06s/it, episode=300, return=-5817.880, makespan=4554.530]

# %%
from raw_PPO import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=5*10*12, action_d=5*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 30/30 [02:06<00:00,  4.21s/it, episode=300, return=-1283.243, makespan=1104.275]

# %%
from raw_PPO import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*10*12, action_d=10*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 30/30 [07:00<00:00, 14.03s/it, episode=300, return=-2435.494, makespan=2052.283]

# %%
from raw_PPO import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=20*10*12, action_d=20*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=500)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 50/50 [52:45<00:00, 63.30s/it, episode=500, return=-4993.023, makespan=3997.674]
