# %%
from raw_DDPG import DDPG
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = DDPG(hidden_dim=64, state_dim=5*5*12, action_dim=5*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Iteration 0:   0%|          | 0/30 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\raw_DDPG.py:185: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(transition_dict['states'], dtype=torch.float).to(self.device)
# Iteration 0: 100%|██████████| 30/30 [02:16<00:00,  4.56s/it, episode=30, return=-1229.104, makespan=1049.350]
# Iteration 1: 100%|██████████| 30/30 [02:10<00:00,  4.36s/it, episode=60, return=-1175.452, makespan=1026.348]
# Iteration 2: 100%|██████████| 30/30 [02:04<00:00,  4.16s/it, episode=90, return=-1147.357, makespan=1000.916]
# Iteration 3: 100%|██████████| 30/30 [02:02<00:00,  4.09s/it, episode=120, return=-1208.395, makespan=1066.258]
# Iteration 4: 100%|██████████| 30/30 [02:06<00:00,  4.21s/it, episode=150, return=-1218.941, makespan=1068.163]
# Iteration 5: 100%|██████████| 30/30 [02:08<00:00,  4.28s/it, episode=180, return=-1195.038, makespan=1051.989]
# Iteration 6: 100%|██████████| 30/30 [02:39<00:00,  5.32s/it, episode=210, return=-1181.732, makespan=1024.857]
# Iteration 7: 100%|██████████| 30/30 [02:15<00:00,  4.52s/it, episode=240, return=-1214.827, makespan=1063.209]
# Iteration 8: 100%|██████████| 30/30 [02:19<00:00,  4.65s/it, episode=270, return=-1304.653, makespan=1144.045]
# Iteration 9: 100%|██████████| 30/30 [02:13<00:00,  4.45s/it, episode=300, return=-1305.197, makespan=1142.452]

# %%
from raw_DDPG import DDPG
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = DDPG(hidden_dim=64, state_dim=10*5*12, action_dim=10*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Iteration 0: 100%|██████████| 30/30 [06:06<00:00, 12.22s/it, episode=30, return=-1764.913, makespan=1435.765]
# Iteration 1: 100%|██████████| 30/30 [07:14<00:00, 14.47s/it, episode=60, return=-1767.716, makespan=1423.900]
# Iteration 2: 100%|██████████| 30/30 [07:17<00:00, 14.58s/it, episode=90, return=-1898.688, makespan=1547.962]
# Iteration 3: 100%|██████████| 30/30 [07:22<00:00, 14.74s/it, episode=120, return=-1988.836, makespan=1618.990]
# Iteration 4: 100%|██████████| 30/30 [07:16<00:00, 14.55s/it, episode=150, return=-1966.729, makespan=1608.454]
# Iteration 5: 100%|██████████| 30/30 [07:11<00:00, 14.39s/it, episode=180, return=-1980.319, makespan=1619.972]
# Iteration 6: 100%|██████████| 30/30 [07:22<00:00, 14.76s/it, episode=210, return=-1965.673, makespan=1601.129]
# Iteration 7: 100%|██████████| 30/30 [07:15<00:00, 14.51s/it, episode=240, return=-2028.141, makespan=1668.346]
# Iteration 8: 100%|██████████| 30/30 [07:24<00:00, 14.82s/it, episode=270, return=-1973.090, makespan=1621.085]
# Iteration 9: 100%|██████████| 30/30 [07:27<00:00, 14.93s/it, episode=300, return=-2082.810, makespan=1693.968]

# %%
from raw_DDPG import DDPG
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = DDPG(hidden_dim=64, state_dim=20*5*12, action_dim=20*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Iteration 0: 100%|██████████| 30/30 [28:30<00:00, 57.01s/it, episode=30, return=-3791.235, makespan=2885.797]
# Iteration 1: 100%|██████████| 30/30 [34:48<00:00, 69.60s/it, episode=60, return=-4447.768, makespan=3279.092]
# Iteration 2: 100%|██████████| 30/30 [32:56<00:00, 65.87s/it, episode=90, return=-4264.620, makespan=3251.193]
# Iteration 3: 100%|██████████| 30/30 [32:27<00:00, 64.92s/it, episode=120, return=-4283.333, makespan=3284.564]
# Iteration 4: 100%|██████████| 30/30 [32:16<00:00, 64.54s/it, episode=150, return=-4310.805, makespan=3288.406]
# Iteration 5: 100%|██████████| 30/30 [33:39<00:00, 67.31s/it, episode=180, return=-4546.178, makespan=3489.992]
# Iteration 6: 100%|██████████| 30/30 [34:30<00:00, 69.02s/it, episode=210, return=-4653.031, makespan=3585.234]
# Iteration 7: 100%|██████████| 30/30 [34:43<00:00, 69.45s/it, episode=240, return=-4722.312, makespan=3611.737]
# Iteration 8: 100%|██████████| 30/30 [35:01<00:00, 70.06s/it, episode=270, return=-4862.997, makespan=3699.979]
# Iteration 9: 100%|██████████| 30/30 [33:30<00:00, 67.01s/it, episode=300, return=-4669.928, makespan=3591.762]

# %%
from raw_DDPG import DDPG
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = DDPG(hidden_dim=64, state_dim=5*10*12, action_dim=5*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Iteration 0: 100%|██████████| 30/30 [01:35<00:00,  3.17s/it, episode=30, return=-595.876, makespan=504.718]
# Iteration 1: 100%|██████████| 30/30 [01:37<00:00,  3.24s/it, episode=60, return=-621.808, makespan=531.041]
# Iteration 2: 100%|██████████| 30/30 [01:44<00:00,  3.47s/it, episode=90, return=-721.092, makespan=613.563]
# Iteration 3: 100%|██████████| 30/30 [01:47<00:00,  3.59s/it, episode=120, return=-724.202, makespan=615.657]
# Iteration 4: 100%|██████████| 30/30 [01:52<00:00,  3.74s/it, episode=150, return=-741.994, makespan=629.129]
# Iteration 5: 100%|██████████| 30/30 [01:50<00:00,  3.68s/it, episode=180, return=-717.062, makespan=609.109]
# Iteration 6: 100%|██████████| 30/30 [01:50<00:00,  3.68s/it, episode=210, return=-722.462, makespan=612.637]
# Iteration 7: 100%|██████████| 30/30 [01:50<00:00,  3.69s/it, episode=240, return=-752.747, makespan=646.528]
# Iteration 8: 100%|██████████| 30/30 [01:51<00:00,  3.71s/it, episode=270, return=-758.699, makespan=651.195]
# Iteration 9: 100%|██████████| 30/30 [01:52<00:00,  3.76s/it, episode=300, return=-792.556, makespan=680.226]

# %%
from raw_DDPG import DDPG
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = DDPG(hidden_dim=64, state_dim=10*10*12, action_dim=10*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Iteration 0: 100%|██████████| 30/30 [04:46<00:00,  9.55s/it, episode=30, return=-852.025, makespan=675.096]
# Iteration 1: 100%|██████████| 30/30 [04:38<00:00,  9.29s/it, episode=60, return=-904.191, makespan=733.609]
# Iteration 2: 100%|██████████| 30/30 [04:48<00:00,  9.63s/it, episode=90, return=-995.040, makespan=798.112]
# Iteration 3: 100%|██████████| 30/30 [05:13<00:00, 10.44s/it, episode=120, return=-1058.254, makespan=849.301]
# Iteration 4: 100%|██████████| 30/30 [05:26<00:00, 10.89s/it, episode=150, return=-1059.176, makespan=845.387]
# Iteration 5: 100%|██████████| 30/30 [05:45<00:00, 11.51s/it, episode=180, return=-1254.619, makespan=973.624]
# Iteration 6: 100%|██████████| 30/30 [06:16<00:00, 12.56s/it, episode=210, return=-1285.142, makespan=1018.278]
# Iteration 7: 100%|██████████| 30/30 [06:16<00:00, 12.54s/it, episode=240, return=-1262.917, makespan=980.785]
# Iteration 8: 100%|██████████| 30/30 [06:12<00:00, 12.41s/it, episode=270, return=-1246.892, makespan=981.837]
# Iteration 9: 100%|██████████| 30/30 [06:28<00:00, 12.96s/it, episode=300, return=-1267.168, makespan=987.748]

# %%
from raw_DDPG import DDPG
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = DDPG(hidden_dim=64, state_dim=20*10*12, action_dim=20*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Iteration 0: 100%|██████████| 30/30 [15:17<00:00, 30.59s/it, episode=30, return=-1589.225, makespan=1198.848]
# Iteration 1: 100%|██████████| 30/30 [19:58<00:00, 39.94s/it, episode=60, return=-1868.233, makespan=1353.382]
# Iteration 2: 100%|██████████| 30/30 [23:23<00:00, 46.78s/it, episode=90, return=-2291.218, makespan=1588.899]
# Iteration 3: 100%|██████████| 30/30 [26:24<00:00, 52.83s/it, episode=120, return=-2321.258, makespan=1591.721]
# Iteration 4: 100%|██████████| 30/30 [26:31<00:00, 53.06s/it, episode=150, return=-2308.172, makespan=1593.239]
# Iteration 5: 100%|██████████| 30/30 [25:09<00:00, 50.32s/it, episode=180, return=-2316.883, makespan=1629.383]
# Iteration 6: 100%|██████████| 30/30 [26:13<00:00, 52.45s/it, episode=210, return=-2348.497, makespan=1641.077]
# Iteration 7: 100%|██████████| 30/30 [27:26<00:00, 54.88s/it, episode=240, return=-2377.875, makespan=1654.752]
# Iteration 8: 100%|██████████| 30/30 [26:04<00:00, 52.16s/it, episode=270, return=-2449.579, makespan=1677.633]
# Iteration 9: 100%|██████████| 30/30 [26:16<00:00, 52.55s/it, episode=300, return=-2480.343, makespan=1739.790]
