# %%
# dataset: 5*5,10*5,20*5,5*10，10*10，20*10 tran<process
ins_1 = ['IS{}J{}M{}R{}'.format(3, 5, 5, i+10) for i in range(10)]
ins_2 = ['IS{}J{}M{}R{}'.format(3, 10, 5, i+10) for i in range(10)]
ins_3 = ['IS{}J{}M{}R{}'.format(3, 20, 5, i+10) for i in range(10)]
ins_4 = ['IS{}J{}M{}R{}'.format(3, 5, 10, i+10) for i in range(10)]
ins_5 = ['IS{}J{}M{}R{}'.format(3, 10, 10, i+10) for i in range(10)]
ins_6 = ['IS{}J{}M{}R{}'.format(3, 20, 10, i+10) for i in range(10)]
ins_7 = ['IS{}J{}M{}R{}'.format(3, 30, 10, i+10) for i in range(10)]
# import rules
from PDR import Random,SPT,FIFO,SSO,MWKR
r1,r2,r3,r4,r5,r6,r7 = Random(ins_1),Random(ins_2),Random(ins_3),Random(ins_4),Random(ins_5),Random(ins_6),Random(ins_7)
s1,s2,s3,s4,s5,s6,s7 = SPT(ins_1),SPT(ins_2),SPT(ins_3),SPT(ins_4),SPT(ins_5),SPT(ins_6),SPT(ins_7)
f1,f2,f3,f4,f5,f6,f7 = FIFO(ins_1),FIFO(ins_2),FIFO(ins_3),FIFO(ins_4),FIFO(ins_5),FIFO(ins_6),FIFO(ins_7)
m1,m2,m3,m4,m5,m6,m7 = SSO(ins_1),SSO(ins_2),SSO(ins_3),SSO(ins_4),SSO(ins_5),SSO(ins_6),SSO(ins_7)
MW1,MW2,MW3,MW4,MW5,MW6,MW7 = MWKR(ins_1),MWKR(ins_2),MWKR(ins_3),MWKR(ins_4),MWKR(ins_5),MWKR(ins_6),MWKR(ins_7)

p1_result = {
    'random':[sum(r1)/len(r1),sum(r2)/len(r2),sum(r3)/len(r3),sum(r4)/len(r4),sum(r5)/len(r5),sum(r6)/len(r6),sum(r7)/len(r7)],
    'SPT': [sum(s1)/len(s1),sum(s2)/len(s2),sum(s3)/len(s3),sum(s4)/len(s4),sum(s5)/len(s5),sum(s6)/len(s6),sum(s7)/len(s7)],
    'FIFO': [sum(f1)/len(f1),sum(f2)/len(f2),sum(f3)/len(f3),sum(f4)/len(f4),sum(f5)/len(f5),sum(f6)/len(f6),sum(f7)/len(f7)],
    'SSO': [sum(m1)/len(m1),sum(m2)/len(m2),sum(m3)/len(m3),sum(m4)/len(m4),sum(m5)/len(m5),sum(m6)/len(m6),sum(m7)/len(m7)],
    'MWKR': [sum(MW1)/len(MW1),sum(MW2)/len(MW2),sum(MW3)/len(MW3),sum(MW4)/len(MW4),sum(MW5)/len(MW5),sum(MW6)/len(MW6),sum(MW7)/len(MW7)]
}
print(p1_result)
# Out:
# {'random': [649.39, 883.26, 1735.44, 483.15, 514.53, 778.5899999999999, 1157.09], 'SPT': [601.8299999999999, 873.1700000000001, 1658.27, 381.88, 475.81000000000006, 839.03, 1138.35], 'FIFO': [495.24000000000007, 729.1500000000001, 1619.4999999999998, 397.94, 493.43, 723.42, 1041.9199999999998], 'SSO': [532.42, 764.8000000000001, 1788.0600000000002, 415.84000000000003, 480.89, 750.9300000000001, 1090.84], 'MWKR': [491.24000000000007, 710.38, 1618.3600000000001, 394.41, 440.48, 676.1, 997.8800000000001]}

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=5*5*12, action_d=5*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=1000)
# Out:
# Device:  cuda
# Iteration 0:   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\HR_DRL.py:150: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(states, dtype=torch.float).to(device)
# ...
# Iteration 9: 100%|██████████| 100/100 [05:08<00:00,  3.08s/it, episode=1000, return=-532.937]
# {'M1': [['J2', 0, 78.0], ['J1', 78.0, 111.2], ['J2', 111.2, 143.0], ['J3', 143.0, 162.0], ['J5', 162.0, 178.2]], 'M2': [['J3', 0, 74.9], ['J5', 74.9, 135.1], ['J2', 143.0, 245.0], ['J4', 380.0]], 'M3': [['J1', 0, 50.4]], 'M4': [['J1', 135.1, 168.4], ['J3', 178.2, 196.8], ['J5', 196.8, 233.4]], 'M5': [['J4', 0, 179.0], ['J4', 179.0, 380.0]]}

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*5*12, action_d=10*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=1000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 100/100 [08:36<00:00,  5.16s/it, episode=1000, return=-820.055]
# {'M1': [['J7', 0, 58.2], ['J9', 58.2, 167.0], ['J2', 167.0, 333.4], ['J10', 333.4, 560.6]], 'M2': [['J6', 0, 54.0], ['J8', 54.0, 105.5], ['J7', 105.5, 137.1], ['J7', 137.1, 307.6], ['J3', 307.6, 362.1], ['J3', 362.1, 384.1], ['J4', 384.1, 441.6], ['J4', 441.6, 469.0], ['J4', 469.0, 621.5], ['J2', 621.5, 654.5]], 'M3': [['J6', 54.0, 166.2], ['J8', 166.2, 305.6], ['J8', 305.6, 355.5], ['J1', 355.5, 503.2], ['J1', 503.2, 631.0], ['J10', 723.3]], 'M4': [['J5', 0, 102.6], ['J1', 102.6, 196.2], ['J9', 196.2, 351.2], ['J5', 351.2, 489.2], ['J5', 489.2, 624.3], ['J10', 624.3, 723.3]], 'M5': [['J6', 166.2, 244.3], ['J3', 384.1, 485.3], ['J9', 489.2, 637.7], ['J2', 654.5]]}

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=20*5*12, action_d=20*5,actor_lr=5e-5, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 5, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=1000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 100/100 [16:47<00:00, 10.07s/it, episode=1000, return=-1770.272]
# ...

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=5*10*12, action_d=5*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=1000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 100/100 [06:37<00:00,  3.97s/it, episode=1000, return=-532.618]
# {'M1': [['J1', 37.2, 78.6], ['J1', 78.6, 309.2]], 'M2': [['J4', 173.3, 209.9]], 'M3': [['J2', 0, 64.2]], 'M4': [['J2', 92.7, 154.7], ['J5', 171.4, 271.4]], 'M5': [['J5', 0, 37.2], ['J3', 37.2, 77.2]], 'M6': [['J2', 64.2, 92.7], ['J4', 149.0, 173.3]], 'M7': [], 'M8': [['J4', 37.2, 149.0]], 'M9': [['J5', 37.2, 171.4], ['J3', 215.8, 268.8], ['J1', 309.2]], 'M10': [['J3', 77.2, 215.8]]}

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*10*12, action_d=10*10, actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 10, i + 10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train, episodes=1000)
# Out:
# Device:  cuda
# Iteration 0:   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\HR_DRL.py:150: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(states, dtype=torch.float).to(device)
# ...
# Iteration 9: 100%|██████████| 100/100 [10:02<00:00,  6.03s/it, episode=1000, return=-632.104]
# ...

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=512, state_d=20*10*12, action_d=20*10,actor_lr=5e-5, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=1000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 100/100 [22:49<00:00, 13.70s/it, episode=1000, return=-861.773]
# ...

# %%
from HR_DRL import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=5*10*12, action_d=5*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=300)
# Out:
# Device:  cuda
# Iteration 0:   0%|          | 0/30 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\HR_DRL.py:150: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(states, dtype=torch.float).to(device)
# ...
# Iteration 9: 100%|██████████| 30/30 [01:55<00:00,  3.83s/it, episode=300, return=-533.362, makespan=456.863]
# {'M1': [['J1', 155.2, 385.8]], 'M2': [['J3', 195.8, 213.8], ['J2', 250.7, 269.3]], 'M3': [['J3', 37.6, 97.6], ['J5', 155.2, 196.0]], 'M4': [['J4', 255.3, 377.3]], 'M5': [['J1', 0, 37.6], ['J2', 37.6, 80.4], ['J3', 97.6, 195.8]], 'M6': [['J5', 196.0, 237.4]], 'M7': [], 'M8': [['J5', 237.4, 267.4], ['J1', 385.8]], 'M9': [['J2', 155.2, 250.7]], 'M10': [['J4', 0, 155.2], ['J4', 155.2, 255.3]]}
