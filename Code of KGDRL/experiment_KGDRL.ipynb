# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=5*5*12, action_d=5*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 5, i+10) for i in range(10)]
return_list_1, makespan_list_1, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 200/200 [10:45<00:00,  3.23s/it, episode=2000, return=-535.140, makespan=496.032, min_makespan=426.980]
# {'M1': [['J2', 0, 78.0], ['J3', 78.0, 106.0], ['J2', 106.0, 137.8], ['J4', 137.8, 163.0], ['J1', 163.0, 187.2]], 'M2': [['J3', 0, 74.9], ['J4', 163.0, 232.0]], 'M3': [['J4', 0, 40.0], ['J1', 74.9, 125.3]], 'M4': [['J3', 106.0, 124.6], ['J2', 137.8, 165.7], ['J1', 187.2, 220.5], ['J5', 288.7]], 'M5': [['J5', 0, 155.2], ['J5', 155.2, 288.7]]}

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*5*12, action_d=10*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 5, i+10) for i in range(10)]
return_list_2, makespan_list_2, instance_makespan_2 = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 200/200 [17:06<00:00,  5.13s/it, episode=2000, return=-827.840, makespan=772.705, min_makespan=688.990]
# {'M1': [['J4', 0, 162.2], ['J2', 162.2, 328.6], ['J3', 328.6, 356.0], ['J6', 388.5, 402.7]], 'M2': [['J1', 0, 52.0], ['J9', 52.0, 86.0], ['J1', 86.0, 112.2], ['J3', 112.2, 124.2], ['J9', 124.2, 143.4], ['J6', 143.4, 206.4], ['J4', 206.4, 233.8], ['J10', 233.8, 313.8], ['J8', 313.8, 365.3], ['J6', 365.3, 388.5], ['J10', 388.5, 400.5], ['J10', 400.5, 566.5], ['J2', 717.7]], 'M3': [['J7', 28.8, 212.4], ['J1', 212.4, 340.2], ['J4', 340.2, 520.7], ['J2', 520.7, 717.7]], 'M4': [['J7', 0, 28.8], ['J3', 28.8, 110.7], ['J5', 110.7, 213.3], ['J5', 213.3, 362.3], ['J5', 362.3, 497.4], ['J8', 497.4, 629.4]], 'M5': [['J9', 143.4, 291.9], ['J7', 328.6, 446.3], ['J8', 629.4, 652.5]]}

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=20*5*12, action_d=20*5,actor_lr=5e-5, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 5, i+10) for i in range(10)]
return_list_3, makespan_list_3, instance_makespan_3 = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 200/200 [38:25<00:00, 11.53s/it, episode=2000, return=-1750.595, makespan=1642.176, min_makespan=1510.760]
# ...

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*5*12, action_d=10*5,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 5, 10, i+10) for i in range(10)]
return_list_4, makespan_list_4, instance_makespan_4 = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 200/200 [13:03<00:00,  3.92s/it, episode=2000, return=-473.883, makespan=398.054, min_makespan=333.820]
# {'M1': [['J4', 0, 51.6], ['J4', 51.6, 173.0]], 'M2': [['J2', 120.0, 138.6], ['J1', 174.0, 201.9]], 'M3': [['J3', 0, 60.0]], 'M4': [['J3', 97.8, 157.8], ['J4', 173.0]], 'M5': [['J2', 53.5, 120.0]], 'M6': [['J3', 60.0, 97.8], ['J1', 126.3, 174.0]], 'M7': [['J2', 0, 53.5]], 'M8': [['J5', 0, 88.4], ['J5', 88.4, 236.4]], 'M9': [['J5', 236.4]], 'M10': [['J1', 0, 126.3]]}

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=64, state_d=10*10*12, action_d=10*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 10, 10, i+10) for i in range(10)]
return_list_5, makespan_list_5, instance_makespan_5 = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# Iteration 0:   0%|          | 0/200 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\HR_DRL_busy_balance.py:181: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(states, dtype=torch.float).to(device)
# ...
# Iteration 9: 100%|██████████| 200/200 [20:03<00:00,  6.02s/it, episode=2000, return=-554.547, makespan=459.586, min_makespan=411.870]
# ...

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=512, state_d=20*10*12, action_d=20*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 10, i+10) for i in range(10)]
return_list_6, makespan_list_6, instance_makespan_6 = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# ...
# Iteration 9: 100%|██████████| 200/200 [47:02<00:00, 14.11s/it, episode=2000, return=-865.661, makespan=751.880, min_makespan=683.520]
# ...

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=512, state_d=20*10*12, action_d=20*10,actor_lr=5e-5, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 20, 10, i+10) for i in range(10)]
return_list_6, makespan_list_6, instance_makespan_6 = my_drl.train_loop(instance_list=instance_train,episodes=2000)
# Out:
# Device:  cuda
# Iteration 0:   0%|          | 0/200 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\HR_DRL_busy_balance.py:181: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(states, dtype=torch.float).to(device)
# ...
# Iteration 9: 100%|██████████| 200/200 [51:17<00:00, 15.39s/it, episode=2000, return=-855.581, makespan=742.253, min_makespan=683.800]
# ...

# %%
import pandas as pd
makespan_data = pd.DataFrame({'5*5':instance_makespan,'10*5':instance_makespan_2,
                              '20*5':instance_makespan_3,'5*10':instance_makespan_4,
                              '10*10':instance_makespan_5,
                              '20*10':instance_makespan_6
                                })
makespan_data.to_csv('D:/记录/课程、比赛/研二/HR_based DRL in JSRS/instances_makespan_3.csv')

# %%
from HR_DRL_busy_balance import PPO
import numpy as np
import random
import torch
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
my_drl = PPO(hidden_dim=1024, state_d=30*10*12, action_d=30*10,actor_lr=5e-4, critic_lr=1e-5)
instance_train = ['IS{}J{}M{}R{}'.format(3, 30, 10, i+10) for i in range(10)]
return_list, makespan_list, instance_makespan = my_drl.train_loop(instance_list=instance_train,episodes=1000)
# Out:
# Device:  cuda
# Iteration 0:   0%|          | 0/100 [00:00<?, ?it/s]C:\Users\ASUS\Desktop\JSRS\HR_DRL_busy_balance.py:181: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:233.)
#   states = torch.tensor(states, dtype=torch.float).to(device)
# ...
# Iteration 3:  24%|██▍       | 24/100 [12:16<38:51, 30.68s/it, episode=320, return=-1298.567, makespan=1125.262, min_makespan=1065.720]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 10
#       8 my_drl = PPO(hidden_dim=1024, state_d=30*10*12, action_d=30*10,actor_lr=5e-4, critic_lr=1e-5)
#       9 instance_train = ['IS{}J{}M{}R{}'.format(3, 30, 10, i+10) for i in range(10)]
# ...
